# %% [markdown]
# # Travail pratique \#1 - Traitements d'images élémentaires
#
# ## Identification
#
# - Nom : Jacob-Simard
# - Prénom : Raphaël
# - Code permanent : JACR26038907
# - Cours : INF600f - H2022
# - Équipe : 9

# %% [markdown]
# ## Importations de modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
import skimage

EX1_IMG1 = "data/tp1_ex1_img1.tiff"
EX1_IMG2 = "data/tp1_ex1_img2.tiff"
EX2_IMG = "data/tp1_ex2_logo.tiff"
EX3_IMG = "data/tp1_ex3_livre_mystere.png"

# %% [markdown]
# ## Exercice 1

# %%
# Chargement des images

retine_img1 = imageio.imread(EX1_IMG1)
retine_img2 = imageio.imread(EX1_IMG2)

# affichage des images

plt.figure(figsize=(15,10))
plt.subplot(121)
plt.imshow(retine_img1)
plt.title("Rétine 1 - " + str(retine_img1.shape))
plt.subplot(122)
plt.imshow(retine_img2)
plt.title("Rétine 2 - " + str(retine_img2.shape))
plt.show()

# %% [markdown]
# On peut voir que les pixels des images sont déjà représentées comme valeurs unique plutôt que RGB.
